# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm

# %% [markdown]
# ## load data

# %%
fname_data = 'assignment_11_data.csv'

feature = np.genfromtxt(fname_data, delimiter=',')

x = feature[:,0]
y = feature[:,1]

number_data     = np.size(feature, 0)
number_feature  = np.size(feature, 1)

print('number of data : {}'.format(number_data))
print('number of feature : {}'.format(number_feature))
# Out:
# number of data : 1000
# number of feature : 2

# %% [markdown]
# ## plot the input data

# %%
plt.figure(figsize=(8,8))   
plt.title('input data')

plt.scatter(x, y, color='blue')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## compute distance
# - feature : $n \times m$, center : $1 \times m$, distance : $n \times 1$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_distance(feature, center):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    error = feature - center
    distance = np.sum(np.square(error), axis =1)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return distance

# %% [markdown]
# ## compute centroid
# - feature : $n \times m$, label_feature : $n \times 1$, value_label : $1 \times 1$, centroid : $1 \times m$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_centroid(feature, label_feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    x = []
    y = []
    
    for i in range(number_data):
        if label_feature[i] == label:
            x.append(feature[i,0])
            y.append(feature[i,1])
            
    if len(x)==0:
        cen_x = 0
    else:
        cen_x = np.mean(np.asarray(x))
        
    if len(y)==0:
        cen_y = 0
    else:
        cen_y = np.mean(np.asarray(y))
    
    centroid = np.array([cen_x, cen_y])

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return centroid

# %% [markdown]
# ## compute label
# - distance : $n \times k$, label_feature : $n \times 1$
# - $n$ : number of data, $k$ : number of clusters

# %%
def compute_label(distance):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    index = []
    
    for i in range(len(distance)):
        k = distance[i].argmin()
        index.append(k)
        
    label_feature = np.asarray(index)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    
    return label_feature

# %%
def compute_loss(feature, label, number_cluster, centroid):
    ans = 0
    data = np.c_[feature,label]
    
    for k in range(number_cluster):
        ans = ans + sum(compute_distance(data[data[:,2]==k][:,:2], centroid[k]))
        
    ans = ans / number_data
    
    return ans

# %% [markdown]
# ## the number of clusters $K = 2$

# %%
number_cluster          = 2
number_iteration        = 100     # you can modify this value
loss_iteration_02       = np.zeros(number_iteration)
centroid_iteration_02   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_02        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

dis = np.zeros(shape=(number_data, number_cluster))
cen = np.zeros(shape=(number_cluster, number_feature))

for i in range(number_iteration):
    for k in range(2):
        cen[k] = compute_centroid(feature, label_feature_02, k)
        dis[:,k] = compute_distance(feature, cen[k])
    label_feature_02 = compute_label(dis)
    loss = compute_loss(feature, label_feature_02, 2, cen)
    centroid_iteration_02[i] = cen
    loss_iteration_02[i] = loss

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 4$

# %%
number_cluster          = 4
number_iteration        = 100     # you can modify this value
loss_iteration_04       = np.zeros(number_iteration)
centroid_iteration_04   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_04        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

dis = np.zeros(shape=(number_data, number_cluster))
cen = np.zeros(shape=(number_cluster, number_feature))

for i in range(number_iteration):
    for k in range(4):
        cen[k] = compute_centroid(feature, label_feature_04, k)
        dis[:,k] = compute_distance(feature, cen[k])
    label_feature_04 = compute_label(dis)
    loss = compute_loss(feature, label_feature_04, 4, cen)
    centroid_iteration_04[i] = cen
    loss_iteration_04[i] = loss

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 8$

# %%
number_cluster          = 8
number_iteration        = 100     # you can modify this value
loss_iteration_08       = np.zeros(number_iteration)
centroid_iteration_08   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_08        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

dis = np.zeros(shape=(number_data, number_cluster))
cen = np.zeros(shape=(number_cluster, number_feature))

for i in range(number_iteration):
    for k in range(8):
        cen[k] = compute_centroid(feature, label_feature_08, k)
        dis[:,k] = compute_distance(feature, cen[k])
    label_feature_08 = compute_label(dis)
    loss = compute_loss(feature, label_feature_08, 8, cen)
    centroid_iteration_08[i] = cen
    loss_iteration_08[i] = loss

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 16$

# %%
number_cluster          = 16
number_iteration        = 100     # you can modify this value
loss_iteration_16       = np.zeros(number_iteration)
centroid_iteration_16   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_16        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

dis = np.zeros(shape=(number_data, number_cluster))
cen = np.zeros(shape=(number_cluster, number_feature))

for i in range(number_iteration):
    for k in range(16):
        cen[k] = compute_centroid(feature, label_feature_16, k)
        dis[:,k] = compute_distance(feature, cen[k])
    label_feature_16 = compute_label(dis)
    loss = compute_loss(feature, label_feature_16, 16, cen)
    centroid_iteration_16[i] = cen
    loss_iteration_16[i] = loss

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
def function_result_01():

    print("final loss (K=2) = {:13.10f}".format(loss_iteration_02[-1]))

# %%
def function_result_02():

    print("final loss (K=4) = {:13.10f}".format(loss_iteration_04[-1]))

# %%
def function_result_03():

    print("final loss (K=8) = {:13.10f}".format(loss_iteration_08[-1]))

# %%
def function_result_04():

    print("final loss (K=16) = {:13.10f}".format(loss_iteration_16[-1]))

# %%
def function_result_05():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=2)')

    plt.plot(loss_iteration_02, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_06():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=4)')

    plt.plot(loss_iteration_04, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_07():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=8)')

    plt.plot(loss_iteration_08, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_08():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=16)')

    plt.plot(loss_iteration_16, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_09():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    for i in range(len(centroid_iteration_02[0,:])):
        x_02 = centroid_iteration_02[:,i][:,0]
        y_02 = centroid_iteration_02[:,i][:,1]
        col = np.random.rand(3)
        plt.plot(x_02, y_02, color = col, label = 'cluster=%d' %i)
        
    x_02 = centroid_iteration_02[0][:,0]
    y_02 = centroid_iteration_02[0][:,1]
    plt.scatter(x_02, y_02, color = 'blue', label = 'initial')
    
    x_02 = centroid_iteration_02[len(centroid_iteration_02)-1][:,0]
    y_02 = centroid_iteration_02[len(centroid_iteration_02)-1][:,1]
    plt.scatter(x_02, y_02, color = 'red', marker = 's', label = 'final')
    
    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_10():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    for i in range(len(centroid_iteration_04[0,:])):
        x_04 = centroid_iteration_04[:,i][:,0]
        y_04 = centroid_iteration_04[:,i][:,1]
        col = np.random.rand(3)
        plt.plot(x_04, y_04, color = col, label = 'cluster=%d' %i)
        
    x_04 = centroid_iteration_04[0][:,0]
    y_04 = centroid_iteration_04[0][:,1]
    plt.scatter(x_04, y_04, color = 'blue', label = 'initial')
    
    x_04 = centroid_iteration_04[len(centroid_iteration_04)-1][:,0]
    y_04 = centroid_iteration_04[len(centroid_iteration_04)-1][:,1]
    plt.scatter(x_04, y_04, color = 'red', marker = 's', label = 'final')
    
    plt.legend()
    plt.tight_layout()
    plt.show()


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_11():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    for i in range(len(centroid_iteration_08[0,:])):
        x_08 = centroid_iteration_08[:,i][:,0]
        y_08 = centroid_iteration_08[:,i][:,1]
        col = np.random.rand(3)
        plt.plot(x_08, y_08, color = col, label = 'cluster=%d' %i)
        
    x_08 = centroid_iteration_08[0][:,0]
    y_08 = centroid_iteration_08[0][:,1]
    plt.scatter(x_08, y_08, color = 'blue', label = 'initial')
    
    x_08 = centroid_iteration_08[len(centroid_iteration_08)-1][:,0]
    y_08 = centroid_iteration_08[len(centroid_iteration_08)-1][:,1]
    plt.scatter(x_08, y_08, color = 'red', marker = 's', label = 'final')
    
    plt.legend()
    plt.tight_layout()
    plt.show()


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_12():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    for i in range(len(centroid_iteration_16[0,:])):
        x_16 = centroid_iteration_16[:,i][:,0]
        y_16 = centroid_iteration_16[:,i][:,1]
        col = np.random.rand(3)
        plt.plot(x_16, y_16, color = col, label = 'cluster=%d' %i)
        
    x_16 = centroid_iteration_16[0][:,0]
    y_16 = centroid_iteration_16[0][:,1]
    plt.scatter(x_16, y_16, color = 'blue', label = 'initial')
    
    x_16 = centroid_iteration_16[len(centroid_iteration_16)-1][:,0]
    y_16 = centroid_iteration_16[len(centroid_iteration_16)-1][:,1]
    plt.scatter(x_16, y_16, color = 'red', marker = 's', label = 'final')
    
    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_13():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    data = np.c_[feature,label_feature_02]
    cmap = plt.cm.rainbow
    norm = colors.BoundaryNorm(np.arange(-0.5, 2 + 0.5, 1), cmap.N)
    plot = plt.scatter(data[:,0:2][:,0], data[:,0:2][:,1], c = label_feature_02, norm = norm, s = 30, edgecolor = 'none')

    colorbar = plt.colorbar(plot, ticks = np.arange(0, 2))
    colorbar.ax.set_ylabel('cluster')
    
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_14():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    data = np.c_[feature,label_feature_04]
    cmap = plt.cm.rainbow
    norm = colors.BoundaryNorm(np.arange(-0.5, 4 + 0.5, 1), cmap.N)
    plot = plt.scatter(data[:,0:2][:,0], data[:,0:2][:,1], c = label_feature_04, norm = norm, s = 30, edgecolor = 'none')

    colorbar = plt.colorbar(plot, ticks = np.arange(0, 4))
    colorbar.ax.set_ylabel('cluster')
    
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_15():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    data = np.c_[feature,label_feature_08]
    cmap = plt.cm.rainbow
    norm = colors.BoundaryNorm(np.arange(-0.5, 8 + 0.5, 1), cmap.N)
    plot = plt.scatter(data[:,0:2][:,0], data[:,0:2][:,1], c = label_feature_08, norm = norm, s = 30, edgecolor = 'none')

    colorbar = plt.colorbar(plot, ticks = np.arange(0, 8))
    colorbar.ax.set_ylabel('cluster')
    
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_16():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    data = np.c_[feature,label_feature_16]
    cmap = plt.cm.rainbow
    norm = colors.BoundaryNorm(np.arange(-0.5, 16 + 0.5, 1), cmap.N)
    plot = plt.scatter(data[:,0:2][:,0], data[:,0:2][:,1], c = label_feature_16, norm = norm, s = 30, edgecolor = 'none')

    colorbar = plt.colorbar(plot, ticks = np.arange(0, 16))
    colorbar.ax.set_ylabel('cluster')
    
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
number_result = 16

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# final loss (K=2) = 31.1123356206
# **************************************************
# ## [RESULT 02]
# **************************************************
# final loss (K=4) = 10.5831291650
# **************************************************
# ## [RESULT 03]
# **************************************************
# final loss (K=8) =  5.9642652273
# **************************************************
# ## [RESULT 04]
# **************************************************
# final loss (K=16) =  3.2603908029
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# ...
